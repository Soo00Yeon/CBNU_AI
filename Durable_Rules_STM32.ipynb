# %%
from durable.lang import *

with ruleset('series'):  # 규칙 집합 이름  - series
#High_Performance
    @when_all((m.predicate == 'flash memory requires') & (m.object == 'more than 2MB'))  # flash memory 크기  
    def STM32H7(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32H7 series' })  # 내장된 프로세서 종류 

    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 512KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M7') & (m.subject == c.first.subject))
    def STM32F7(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F7 series' })
        
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 64KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M4') & (m.subject == c.first.subject))
    def STM32F4(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F4 series' })
                       
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 128KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M3') & (m.subject == c.first.subject))
    def STM32F2(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F2 series' })
#Mainstream
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 16KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M0+') & (m.subject == c.first.subject))
    def STM32G0(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32G0 series' })

    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 32KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M4') & (m.subject == c.first.subject))
    def STM32G4(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32G4 series' })
                       
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 16KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M3') & (m.subject == c.first.subject))
    def STM32F1(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F1 series' })
        
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 16KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M0') & (m.subject == c.first.subject))
    def STM32F0(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the',
                       'object': 'STM32F0 series' })
# Ultra_low_power
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 256KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M33') & (m.subject == c.first.subject))
    def STM32L5(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32L5 series' })
        
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 1MB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M4') & (m.subject == c.first.subject))
    def STM32L4P(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32L4+ series' })
                       
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 128KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M4') & (m.subject == c.first.subject))
    def STM32L4(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32L4 series' })
        
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 32KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M3') & (m.subject == c.first.subject))
    def STM32L1(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32L1 series' })
                       
    @when_all(c.first << (m.predicate == 'flash memory requires') & (m.object == 'more than 8KB'),
              (m.predicate == 'requires') & (m.object == 'Cortex-M0+') & (m.subject == c.first.subject))
    def STM32L0(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32L0 series' })

#PRICE
#해당 시리즈의 최대 가격 
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32H7 series'))
    def STM32H7_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 30,770' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F7 series'))
    def STM32F7_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 31,310' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F4 series'))
    def STM32F4_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 30,662' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F2 series'))
    def STM32F2_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 26,602' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32G0 series'))
    def STM32G0_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 10,063' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32G4 series'))
    def STM32G4_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 15,796' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F1 series'))
    def STM32F1_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 20,869' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F0 series'))
    def STM32F0_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 9,132' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32L5 series'))
    def STM32L5_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 15,581' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32L4+ series'))
    def STM32L4P_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 27,357' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32L4 series'))
    def STM32L4_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 27,357' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32L1 series'))
    def STM32L1_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 17,469' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32L0 series'))
    def STM32L0_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 26,953' })
        
        
    @when_all(+m.subject)
    def output(c):
        print('Fact: {0} {1} {2}'.format(c.m.subject, c.m.predicate, c.m.object),'\n')

# %%
assert_fact('series', { 'subject': 'microprocessor A', 'predicate': 'flash memory requires', 
                       'object': 'more than 2MB' })
print('\n')
assert_fact('series', { 'subject': 'microprocessor B', 'predicate': 'flash memory requires', 
                       'object': 'more than 128KB' })
assert_fact('series', { 'subject': 'microprocessor B', 'predicate': 'requires', 'object': 'Cortex-M4' })
print('\n')
assert_fact('series', { 'subject': 'microprocessor C', 'predicate': 'flash memory requires', 
                       'object': 'more than 128KB' })
assert_fact('series', { 'subject': 'microprocessor C', 'predicate': 'requires', 'object': 'Cortex-M3' })
print('\n')
assert_fact('series', { 'subject': 'microprocessor D', 'predicate': 'flash memory requires', 
                       'object': 'more than 512KB' })
assert_fact('series', { 'subject': 'microprocessor D', 'predicate': 'requires', 'object': 'Cortex-M7' })
print('\n')
assert_fact('series', { 'subject': 'microprocessor E', 'predicate': 'flash memory requires', 
                       'object': 'more than 64KB' })
assert_fact('series', { 'subject': 'microprocessor E', 'predicate': 'requires', 'object': 'Cortex-M4' })
# Out:
# Fact: microprocessor A costs up to \ 30,770
#
# Fact: microprocessor A is suitable for using the STM32H7 series
#
# Fact: microprocessor A flash memory requires more than 2MB
#
#
#
# Fact: microprocessor B flash memory requires more than 128KB
#
# Fact: microprocessor B costs up to \ 27,357
#
# Fact: microprocessor B is suitable for using the STM32L4 series
#
# Fact: microprocessor B requires Cortex-M4
#
#
#
# Fact: microprocessor C flash memory requires more than 128KB
#
# Fact: microprocessor C costs up to \ 26,602
#
# Fact: microprocessor C is suitable for using the STM32F2 series
#
# Fact: microprocessor C requires Cortex-M3
#
#
#
# Fact: microprocessor D flash memory requires more than 512KB
#
# Fact: microprocessor D costs up to \ 31,310
#
# Fact: microprocessor D is suitable for using the STM32F7 series
#
# Fact: microprocessor D requires Cortex-M7
#
#
#
# Fact: microprocessor E flash memory requires more than 64KB
#
# Fact: microprocessor E costs up to \ 30,662
#
# ...

# %%
with ruleset('STM32F4 series'): #규칙의 집합 이름 - STM32F4 series
#High_Performance
    @when_all((m.predicate == 'RAM size must be') & (m.object == '384KB'))  # RAM 크기  
    def STM32F469(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F469 line' })

    @when_all(c.first << (m.predicate == 'CPU clock speed must be') & (m.object == '180MHz'), # CPU 클럭 속도  
              (m.predicate == 'RAM size must be') & (m.object == '256KB') & (m.subject == c.first.subject))
    def STM32F429(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F429 line' })
        
    @when_all(c.first << (m.predicate == 'CPU clock speed must be') & (m.object == '180MHz'),
              (m.predicate == 'RAM size must be') & (m.object == '128KB') & (m.subject == c.first.subject))
    def STM32F446 (c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F446 line' })
                       
    @when_all(c.first << (m.predicate == 'CPU clock speed must be') & (m.object == '168MHz'),
              (m.predicate == 'RAM size must be') & (m.object == '192KB') & (m.subject == c.first.subject))
    def STM32F407(c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F407 line' })
        
    @when_all((m.predicate == 'CPU clock speed must be') & (m.object == '84MHz'))
    def STM32F401(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F401 line' })
        
    @when_all(c.first << (m.predicate == 'CPU clock speed must be') & (m.object == '100MHz'),
              (m.predicate == 'RAM size must be') & (m.object == '32KB') & (m.subject == c.first.subject))
    def STM32F411 (c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F411 line' })
        
    @when_all(c.first << (m.predicate == 'CPU clock speed must be') & (m.object == '100MHz'),
              (m.predicate == 'RAM size must be') & (m.object == '128KB') & (m.subject == c.first.subject))
    def STM32F410 (c):
        c.assert_fact({ 'subject': c.first.subject, 'predicate': 'is suitable for using the', 
                       'object': 'STM32F410 line' })
        
    #해당 시리즈의 최대 가격 
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F469 line'))
    def STM32F469_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 28,194' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F429 line'))
    def STM32F429_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 28,315' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F446 line'))
    def STM32F446_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 15,837' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F407 line'))
    def STM32F407_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 22,218' })
        
    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F401 line'))
    def STM32F401_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 11,466' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F411 line'))
    def STM32F411_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 12,289' })

    @when_all((m.predicate == 'is suitable for using the') & (m.object == 'STM32F410 line'))
    def STM32F410_price(c):
        c.assert_fact({ 'subject': c.m.subject, 'predicate': 'costs up to', 'object': '\ 7,797' })
        
    @when_all(+m.subject)
    def output(c):
        print('Fact: {0} {1} {2}'.format(c.m.subject, c.m.predicate, c.m.object),'\n')

# %%
assert_fact('STM32F4 series', { 'subject': 'microprocessor A', 'predicate': 'CPU clock speed must be', 'object': '180MHz' })
assert_fact('STM32F4 series', { 'subject': 'microprocessor A', 'predicate': 'RAM size must be', 'object': '256KB' })
print('\n')
assert_fact('STM32F4 series', { 'subject': 'microprocessor B', 'predicate': 'CPU clock speed must be', 'object': '100MHz' })
assert_fact('STM32F4 series', { 'subject': 'microprocessor B', 'predicate': 'RAM size must be', 'object': '128KB' })
print('\n')
assert_fact('STM32F4 series', { 'subject': 'microprocessor C', 'predicate': 'CPU clock speed must be', 'object': '84MHz' })
# Out:
# Fact: microprocessor A CPU clock speed must be 180MHz
#
# Fact: microprocessor A costs up to \ 28,315
#
# Fact: microprocessor A is suitable for using the STM32F429 line
#
# Fact: microprocessor A RAM size must be 256KB
#
#
#
# Fact: microprocessor B CPU clock speed must be 100MHz
#
# Fact: microprocessor B costs up to \ 7,797
#
# Fact: microprocessor B is suitable for using the STM32F410 line
#
# Fact: microprocessor B RAM size must be 128KB
#
#
#
# Fact: microprocessor C costs up to \ 11,466
#
# Fact: microprocessor C is suitable for using the STM32F401 line
#
# Fact: microprocessor C CPU clock speed must be 84MHz
# {'sid': '0', 'id': 'sid-0', '$s': 1}
